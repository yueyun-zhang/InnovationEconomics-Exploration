# %% [markdown]
# # Basic Research Ratio in VAR analysis

# %%
#libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import seaborn as sns
import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.vector_ar.irf import IRAnalysis
from fredapi import Fred

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Data Transformation to Get B-Ratio from R&D and from patent

# %% [markdown]
# ### 1.1 R&D B-ratio

# %%
# OECD Basic Research Ratio
RD_BRatio = pd.read_excel('Data/OECDBratio1980.xlsx')

# %%
# Mean
print(np.mean(RD_BRatio['Bratio']))
print(np.var(RD_BRatio['Bratio']))
# Out:
# 0.4191832253116552
# 0.0015715734926652859

# %%
RD_BRatio['log_BRatio'] = np.log(RD_BRatio['Bratio'])
RD_BRatio = RD_BRatio[['Year', 'log_BRatio']]

# %% [markdown]
# ### 1.2 Patent B-ratio

# %%
all_USpatent = pd.read_csv('Data/all_patent.csv')

b_patent1 = pd.read_csv('Data/1.csv')
b_patent2 = pd.read_csv('Data/2.csv')
b_patent3 = pd.read_csv('Data/3.csv')
b_patent = pd.concat([b_patent1, b_patent2, b_patent3])
b_patent =  b_patent.groupby(['Year']).count()

patent_df = pd.merge(all_USpatent, b_patent, on='Year').dropna()

patent_df['patent_bratio'] = np.log(patent_df['Name']/patent_df['Number'])
patent_df = patent_df[['Year', 'patent_bratio']]

# %% [markdown]
# ### 1.3 BRatio Description

# %%
B_df = pd.merge(patent_df, RD_BRatio, on='Year', how='outer')

# %%
B_df
# Out:
#     Year  patent_bratio  log_BRatio
# 0   1963            NaN   -1.066201
# 1   1964            NaN   -1.030836
# 2   1965            NaN   -0.992599
# 3   1966            NaN   -0.968898
# 4   1967            NaN   -0.928273
# ..   ...            ...         ...
# 56  2019      -3.585944   -0.808980
# 57  2020      -3.463343   -0.783906
# 58  2021      -3.259641   -0.800440
# 59  2022      -3.220561   -0.805908
# 60  2023      -3.349379         NaN
#
# [61 rows x 3 columns]

# %%
fig, ax1 = plt.subplots()

# Plot Temperature on the primary y-axis
ax1.plot(B_df['Year'], B_df['patent_bratio'], color='tab:red', marker='o')
ax1.set_xlabel('Year')
ax1.set_ylabel('Patenting', color='tab:red')

# Create a twin of the x-axis
ax2 = ax1.twinx()

# Plot Rainfall on the secondary y-axis
ax2.plot(B_df['Year'], B_df['log_BRatio'], color='tab:blue', marker='o')
ax2.set_ylabel('R & D investment', color='tab:blue')

plt.title('Basic Research Over all Research')
plt.show()

# %%
api = "f778a2073453c711be0c316569a478d2"
fred = Fred(api_key=api)

tfp = fred.get_series('RTFPNAUSA632NRUG') #Annual Total Factor Productivity
investment = fred.get_series('GPDIC1') #quarterly real domestic investment
wage = fred.get_series('LES1252881600Q') #quarterly real and seasonally adjusted wage
hours = fred.get_series('B4701C0A222NBEA') #Annual hours worked by full and part time employees

# %%
def transform(data):

    annual_data = {'year': data.resample('Y').mean().index.year,
                   'value':data.resample('Y').mean()}
    annual_data = pd.DataFrame(annual_data).reset_index(drop=True)
    annual_data['value'] = np.log(annual_data['value'])  #log transformation

    df = pd.DataFrame({'year': range(1963, 2023)})

    df = pd.merge(df, annual_data, on='year', how='left')
    return df #between 1963 to 2022

# %%
data = {'year':transform(tfp)['year'],
        'RD_bratio': B_df['log_BRatio'],
        'patent_bratio': B_df['patent_bratio'],
        'tfp': transform(tfp)['value'],
        'gdp': transform(gdp)['value'],
        'investment' : transform(investment)['value'],
        'wage': transform(wage)['value'],
        'hours': transform(hours)['value']}
data = pd.DataFrame(data)

# %%
data = data.dropna()
smdata = data.drop('year', axis=1)

# %% [markdown]
# ### VAR Analysis

# %%
def var_model(data, var, var2):
    model = VAR(data)
    lag_order = model.select_order()  # 2 lags is ideal
    print(lag_order.summary())  
    print(f"Optimal lag order based on AIC: {lag_order.selected_orders['aic']}") #Akaike Information Criterion (AIC) and 
    var_model = model.fit(lag_order.selected_orders['aic'])
    print(var_model.summary())
    irf = var_model.irf(10)
    irf.plot(impulse=var, orth=False)
    plt.show()

    granger_test_x_y = var_model.test_causality(var, var2, kind='f')  # Test if 'x' Granger-causes 'y'
    granger_test_y_x = var_model.test_causality(var2, var, kind='f')  # Test if 'y' Granger-causes 'x'

    print("Granger Causality Test (x -> y):")
    print(granger_test_x_y.summary())
    
    print("\nGranger Causality Test (y -> x):")
    print(granger_test_y_x.summary())

# %% [markdown]
# ### 2.1 Two Variables Analysis (BRatio and Productivity)

# %%
var_model(data[['patent_bratio', 'RD_bratio']], 'RD_bratio', 'patent_bratio')
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0       -6.648      -6.554    0.001297      -6.618
# 1       -8.262      -7.981   0.0002586      -8.172
# 2       -8.586      -8.119   0.0001878      -8.437
# 3      -8.812*     -8.158*  0.0001515*     -8.603*
# 4       -8.658      -7.818   0.0001804      -8.390
# 5       -8.517      -7.490   0.0002148      -8.189
# 6       -8.393      -7.179   0.0002560      -8.005
# 7       -8.268      -6.867   0.0003124      -7.820
# 8       -8.329      -6.741   0.0003270      -7.821
# 9       -8.589      -6.814   0.0002934      -8.021
# 10      -8.684      -6.722   0.0003305      -8.056
# --------------------------------------------------
# Optimal lag order based on AIC: 3
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 08, Dec, 2024
# Time:                     13:47:03
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -8.54844
# Nobs:                     37.0000    HQIC:                  -8.94308
# Log likelihood:           78.4211    FPE:                0.000106353
# AIC:                     -9.15797    Det(Omega_mle):     7.52052e-05
# --------------------------------------------------------------------
# Results for equation patent_bratio
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -0.437938         0.494863           -0.885           0.376
# L1.patent_bratio         1.491127         0.169806            8.781           0.000
# L1.RD_bratio             0.439611         1.089985            0.403           0.687
# L2.patent_bratio        -0.988681         0.269938           -3.663           0.000
# L2.RD_bratio            -1.108721         1.277332           -0.868           0.385
# L3.patent_bratio         0.276556         0.187441            1.475           0.140
# L3.RD_bratio             1.259039         1.020645            1.234           0.217
# ===================================================================================
#
# Results for equation RD_bratio
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -0.105980         0.069667           -1.521           0.128
# L1.patent_bratio         0.073828         0.023906            3.088           0.002
# L1.RD_bratio             0.741266         0.153449            4.831           0.000
# L2.patent_bratio        -0.137622         0.038002           -3.621           0.000
# L2.RD_bratio            -0.086704         0.179824           -0.482           0.630
# L3.patent_bratio         0.059604         0.026388            2.259           0.024
# L3.RD_bratio             0.233489         0.143688            1.625           0.104
# ===================================================================================
#
# Correlation matrix of residuals
#                  patent_bratio  RD_bratio
# patent_bratio         1.000000  -0.191769
# RD_bratio            -0.191769   1.000000
# Granger Causality Test (x -> y):
# Granger causality F-test. H_0: patent_bratio does not Granger-cause RD_bratio. Conclusion: reject H_0 at 5% significance level.
# =============================================
# Test statistic Critical value p-value    df
# ---------------------------------------------
#          5.110          2.758   0.003 (3, 60)
# ---------------------------------------------
#
# Granger Causality Test (y -> x):
# Granger causality F-test. H_0: RD_bratio does not Granger-cause patent_bratio. Conclusion: fail to reject H_0 at 5% significance level.
# =============================================
# Test statistic Critical value p-value    df
# ---------------------------------------------
#         0.7829          2.758   0.508 (3, 60)
# ---------------------------------------------

# %%
var_model(data[['tfp', 'RD_bratio']], 'RD_bratio', 'tfp')
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0       -11.72      -11.63   8.092e-06      -11.69
# 1      -15.99*     -15.71*  1.143e-07*     -15.90*
# 2       -15.86      -15.39   1.301e-07      -15.71
# 3       -15.68      -15.02   1.580e-07      -15.47
# 4       -15.50      -14.66   1.933e-07      -15.23
# 5       -15.34      -14.32   2.330e-07      -15.02
# 6       -15.19      -13.97   2.868e-07      -14.80
# 7       -14.97      -13.57   3.849e-07      -14.52
# 8       -14.98      -13.39   4.228e-07      -14.47
# 9       -14.84      -13.06   5.665e-07      -14.27
# 10      -14.89      -12.93   6.681e-07      -14.26
# --------------------------------------------------
# Optimal lag order based on AIC: 1
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 08, Dec, 2024
# Time:                     13:47:10
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -15.5725
# Nobs:                     39.0000    HQIC:                  -15.7366
# Log likelihood:           203.977    FPE:                1.33677e-07
# AIC:                     -15.8284    Det(Omega_mle):     1.15263e-07
# --------------------------------------------------------------------
# Results for equation tfp
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.029359         0.022420            1.310           0.190
# L1.tfp               0.955929         0.033541           28.500           0.000
# L1.RD_bratio         0.032721         0.030191            1.084           0.278
# ===============================================================================
#
# Results for equation RD_bratio
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const               -0.303136         0.107642           -2.816           0.005
# L1.tfp               0.355386         0.161040            2.207           0.027
# L1.RD_bratio         0.590532         0.144954            4.074           0.000
# ===============================================================================
#
# Correlation matrix of residuals
#                   tfp  RD_bratio
# tfp          1.000000   0.067858
# RD_bratio    0.067858   1.000000
# Granger Causality Test (x -> y):
# Granger causality F-test. H_0: tfp does not Granger-cause RD_bratio. Conclusion: reject H_0 at 5% significance level.
# =============================================
# Test statistic Critical value p-value    df
# ---------------------------------------------
#          4.870          3.974   0.031 (1, 72)
# ---------------------------------------------
#
# Granger Causality Test (y -> x):
# Granger causality F-test. H_0: RD_bratio does not Granger-cause tfp. Conclusion: fail to reject H_0 at 5% significance level.
# =============================================
# Test statistic Critical value p-value    df
# ---------------------------------------------
#          1.175          3.974   0.282 (1, 72)
# ---------------------------------------------

# %%
var_model(data[['tfp', 'patent_bratio']], 'patent_bratio', 'tfp')
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0       -6.712      -6.619    0.001216      -6.683
# 1       -11.83      -11.55   7.319e-06      -11.74
# 2      -12.33*     -11.86*  4.466e-06*     -12.18*
# 3       -12.14      -11.49   5.411e-06      -11.94
# 4       -12.04      -11.20   6.122e-06      -11.77
# 5       -11.81      -10.78   8.003e-06      -11.48
# 6       -11.72      -10.51   9.156e-06      -11.34
# 7       -11.72      -10.32   9.870e-06      -11.27
# 8       -11.84      -10.26   9.724e-06      -11.34
# 9       -11.82      -10.04   1.159e-05      -11.25
# 10      -12.30      -10.34   8.895e-06      -11.67
# --------------------------------------------------
# Optimal lag order based on AIC: 2
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 08, Dec, 2024
# Time:                     13:47:15
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -11.7620
# Nobs:                     38.0000    HQIC:                  -12.0396
# Log likelihood:           133.826    FPE:                5.08186e-06
# AIC:                     -12.1929    Det(Omega_mle):     3.96874e-06
# --------------------------------------------------------------------
# Results for equation tfp
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -0.001723         0.012216           -0.141           0.888
# L1.tfp                   0.998226         0.171712            5.813           0.000
# L1.patent_bratio         0.004862         0.004925            0.987           0.324
# L2.tfp                  -0.008302         0.171345           -0.048           0.961
# L2.patent_bratio        -0.006463         0.004975           -1.299           0.194
# ===================================================================================
#
# Results for equation patent_bratio
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -1.268746         0.344449           -3.683           0.000
# L1.tfp                  -4.663769         4.841633           -0.963           0.335
# L1.patent_bratio         1.271570         0.138857            9.157           0.000
# L2.tfp                   5.716481         4.831270            1.183           0.237
# L2.patent_bratio        -0.602110         0.140265           -4.293           0.000
# ===================================================================================
#
# Correlation matrix of residuals
#                       tfp  patent_bratio
# tfp              1.000000      -0.362214
# patent_bratio   -0.362214       1.000000
# Granger Causality Test (x -> y):
# Granger causality F-test. H_0: tfp does not Granger-cause patent_bratio. Conclusion: fail to reject H_0 at 5% significance level.
# =============================================
# Test statistic Critical value p-value    df
# ---------------------------------------------
#          2.240          3.136   0.115 (2, 66)
# ---------------------------------------------
#
# Granger Causality Test (y -> x):
# Granger causality F-test. H_0: patent_bratio does not Granger-cause tfp. Conclusion: fail to reject H_0 at 5% significance level.
# =============================================
# Test statistic Critical value p-value    df
# ---------------------------------------------
#         0.8512          3.136   0.432 (2, 66)
# ---------------------------------------------

# %% [markdown]
# ### 2.2. Three Variables (BRatio, Output and Productivity)

# %%
var_model(data[['tfp', 'gdp', 'RD_bratio']], 'RD_bratio', 'tfp')
# Out:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0      -18.67      -18.53   7.771e-09      -18.63
# 1      -25.01      -24.45   1.384e-11      -24.83
# 2      -25.66      -24.69   7.354e-12      -25.34
# 3      -25.47      -24.08   9.359e-12      -25.01
# 4      -25.10      -23.30   1.480e-11      -24.51
# 5      -25.13      -22.91   1.703e-11      -24.40
# 6      -25.39      -22.75   1.722e-11      -24.53
# 7      -25.89      -22.84   1.643e-11      -24.90
# 8      -27.31      -23.84   8.890e-12      -26.18
# 9     -33.52*     -29.63*  9.380e-14*     -32.25*
# -------------------------------------------------
# Optimal lag order based on AIC: 9
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun,
# L7.tfp               0.218293         2.025007            0.108           0.914
# L7.gdp               0.432137         1.318594            0.328           0.743
# L7.RD_bratio        -0.370130         0.182615           -2.027           0.043
# L8.tfp               0.710084         1.627412            0.436           0.663
# L8.gdp              -0.019040         1.288117           -0.015           0.988
# L8.RD_bratio         0.068143         0.192678            0.354           0.724
# L9.tfp              -1.211853         0.793113           -1.528           0.127
# L9.gdp               0.718378         0.729545            0.985           0.325
# L9.RD_bratio        -0.136725         0.314437           -0.435           0.664
# ===============================================================================
#
# Results for equation RD_bratio
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const               11.007428         5.767854            1.908           0.056
# L1.tfp               6.945564         1.815606            3.825           0.000
# L1.gdp              -6.296314         0.876031           -7.187           0.000
# L1.RD_bratio        -0.748436         0.141297           -5.297           0.000
# L2.tfp              -5.230492         1.798414           -2.908           0.004
# L2.gdp               6.648229         1.365420            4.869           0.000
# L2.RD_bratio        -0.222065         0.138706           -1.601           0.109
# L3.tfp              -5.603449         2.138333           -2.620           0.009
# L3.gdp              -1.606153         1.168067           -1.375           0.169
# L3.RD_bratio        -0.377439         0.186009           -2.029           0.042
# L4.tfp               9.295255         2.071051            4.488           0.000
# L4.gdp              -6.787288         1.690805           -4.014           0.000
# L4.RD_bratio         0.389727         0.123089            3.166           0.002
# L5.tfp               1.586714         1.381868            1.148           0.251
# L5.gdp               6.177099         1.181079            5.230           0.000
# L5.RD_bratio         1.096672         0.159772            6.864           0.000
# L6.tfp              -5.618703         1.755039           -3.201           0.001
# L6.gdp               3.315511         1.055959            3.140           0.002
# L6.RD_bratio         1.425281         0.184486            7.726           0.000
# L7.tfp               0.342205         1.817421            0.188           0.851
# L7.gdp              -2.866781         1.183423           -2.422           0.015
# L7.RD_bratio         0.970176         0.163895            5.920           0.000
# L8.tfp              -4.494782         1.460584           -3.077           0.002
# L8.gdp               2.788130         1.156070            2.412           0.016
# L8.RD_bratio         0.030196         0.172926            0.175           0.861
# L9.tfp               0.617229         0.711810            0.867           0.386
# L9.gdp              -2.244955         0.654758           -3.429           0.001
# L9.RD_bratio         1.710260         0.282204            6.060           0.000
# ===============================================================================
#
# Correlation matrix of residuals
#                   tfp       gdp  RD_bratio
# tfp          1.000000  0.942638  -0.934319
# gdp          0.942638  1.000000  -0.979800
# RD_bratio   -0.934319 -0.979800   1.000000
# Granger Causality Test (x -> y):
# Granger causality F-test. H_0: tfp does not Granger-cause RD_bratio. Conclusion: reject H_0 at 5% significance level.
# ============================================
# Test statistic Critical value p-value   df
# --------------------------------------------
#          11.71          3.179   0.001 (9, 9)
# --------------------------------------------
#
# Granger Causality Test (y -> x):
# Granger causality F-test. H_0: RD_bratio does not Granger-cause tfp. Conclusion: fail to reject H_0 at 5% significance level.
# ============================================
# Test statistic Critical value p-value   df
# --------------------------------------------
#         0.4527          3.179   0.873 (9, 9)
# --------------------------------------------

# %%
var_model(data[['tfp', 'gdp', 'patent_bratio']], 'patent_bratio', 'tfp')
# Out:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 
# Granger causality F-test. H_0: tfp does not Granger-cause patent_bratio. Conclusion: fail to reject H_0 at 5% significance level.
# ============================================
# Test statistic Critical value p-value   df
# --------------------------------------------
#         0.3773          3.179   0.919 (9, 9)
# --------------------------------------------
#
# Granger Causality Test (y -> x):
# Granger causality F-test. H_0: patent_bratio does not Granger-cause tfp. Conclusion: fail to reject H_0 at 5% significance level.
# ============================================
# Test statistic Critical value p-value   df
# --------------------------------------------
#          1.335          3.179   0.337 (9, 9)
# --------------------------------------------

# %% [markdown]
# ### 1.3 Five variables

# %%
var_model(data[['tfp', 'gdp', 'investment', 'hours', 'RD_bratio']], 'RD_bratio', 'tfp')
# Out:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0      -32.38      -32.16   8.680e-15      -32.30
# 1      -43.90     -42.57*   8.745e-20      -43.44
# 2      -44.60      -42.15   4.790e-20      -43.75
# 3      -45.08      -41.53   3.805e-20      -43.85
# 4      -45.46      -40.79   4.588e-20      -43.85
# 5     -47.65*      -41.87  1.726e-20*     -45.65*
# -------------------------------------------------
# Optimal lag order based on AIC: 5
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 08, Dec, 2024
# Time:                     13:49:16
# --------------------------------------------------------------------
# No. of Equations:         5.00000    BIC:                   -41.8686
# Nobs:                     35.0000    HQIC:                  -45.6513
# Log likelihood:           715.483    FPE:                1.72601e-20
# AIC:                     -47.6456    Det(Omega_mle):     1.07333e-21
# --------------------------------------------------------------------
# Results for equation tfp
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 2.241160         0.836356            2.680           0.007
# L1.tfp               -1.014661         0.464137           -2.186           0.029
# L1.gdp                1.416358         0.488940            2.897           0.004
# L1.investment        -0.043518         0.075261           -0.578           0.563
# L1.hours             -0.906186         0.278494           -3.254           0.001
# L1.RD_bratio          0.073682         0.030401            2.424           0.015
# L2.tfp                1.718802         0.499886            3.438           0.001
# L2.gdp               -2.848471         0.713453           -3.993           0.000
# L2.investment         0.278598         0.081314            3.426           0.001
# L2.hours              0.892995         0.280855            3.180           0.001
# L2.RD_bratio          0.043943         0.024296            1.809           0.071
# L3.tfp               -0.918479         0.556096           -1.652           0.099
# L3.gdp                1.344997         0.664360            2.024           0.043
# L3.investment        -0.154592         0.076644           -2.017           0.044
# L3.hours              0.077829         0.304904            0.255           0.799
# L3.RD_bratio          0.070424         0.026998            2.609           0.009
# L4.tfp                0.738924         0.589532            1.253           0.210
# L4.gdp               -0.723410         0.690428           -1.048           0.295
# L4.investment         0.081013         0.068107            1.189           0.234
# L4.hours              0.110188         0.291396            0.378           0.705
# L4.RD_bratio          0.034924         0.029912            1.168           0.243
# L5.tfp               -1.794337         0.524182           -3.423           0.001
# L5.gdp                1.202771         0.463850            2.593           0.010
# L5.investment         0.085724         0.035438            2.419           0.016
# L5.hours             -0.809115         0.288328           -2.806           0.005
# L5.RD_bratio          0.055810         0.033217            1.680           0.093
# ================================================================================
#
# Results for equation gdp
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 2.424434         2.962443            0.818           0.413
# L1.tfp               -3.705038         1.644011           -2.254           0.024
# L1.gdp                5.948777         1.731867            3.435           0.001
# L1.investment        -0.723971         0.266581           -2.716           0.007
# L1.hours             -0.398686         0.986450           -0.404           0.686
# L1.RD_bratio          0.125581         0.107683            1.166           0.244
# L2.tfp                4.324307         1.770639            2.442           0.015
# L2.gdp               -7.491783         2.527112           -2.965           0.003
# L2.investment         0.481500         0.288020            1.672           0.095
# L2.hours              1.931307         0.994812            1.941           0.052
# L2.RD_bratio          0.061628         0.086060            0.716           0.474
# L3.tfp               -1.010361         1.969740           -0.513           0.608
# L3.gdp                0.875818         2.353220            0.372           0.710
# L3.investment         0.150315         0.271481            0.554           0.580
# L3.hours             -0.849271         1.079995           -0.786           0.432
# L3.RD_bratio          0.130490         0.095629            1.365           0.172
# L4.tfp               -1.699656         2.088173           -0.814           0.416
# L4.gdp                0.683360         2.445553            0.279           0.780
# L4.investment         0.114732         0.241242            0.476           0.634
# L4.hours             -0.127435         1.032150           -0.123           0.902
# L4.RD_bratio          0.156129         0.105952            1.474           0.141
# L5.tfp               -2.892291         1.856696           -1.558           0.119
# L5.gdp                1.626596         1.642997            0.990           0.322
# L5.investment        -0.014544         0.125525           -0.116           0.908
# L5.hours             -1.020499         1.021282           -0.999           0.318
# L5.RD_bratio          0.236235         0.117657            2.008           0.045
# ================================================================================
#
# Results for equation RD_bratio
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const               -12.114589         8.353776           -1.450           0.147
# L1.tfp                3.637843         4.635937            0.785           0.433
# L1.gdp               -6.652162         4.883683           -1.362           0.173
# L1.investment         0.651152         0.751731            0.866           0.386
# L1.hours              1.645571         2.781685            0.592           0.554
# L1.RD_bratio         -0.295919         0.303656           -0.975           0.330
# L2.tfp               -3.178105         4.993014           -0.637           0.524
# L2.gdp                5.099634         7.126190            0.716           0.474
# L2.investment         0.301959         0.812187            0.372           0.710
# L2.hours             -3.484000         2.805264           -1.242           0.214
# L2.RD_bratio         -0.317663         0.242680           -1.309           0.191
# L3.tfp               -2.436997         5.554459           -0.439           0.661
# L3.gdp                5.063856         6.635832            0.763           0.445
# L3.investment        -0.369692         0.765548           -0.483           0.629
# L3.hours             -1.071447         3.045472           -0.352           0.725
# L3.RD_bratio         -0.031177         0.269663           -0.116           0.908
# L4.tfp                3.162185         5.888426            0.537           0.591
# L4.gdp                1.191140         6.896200            0.173           0.863
# L4.investment        -1.047342         0.680278           -1.540           0.124
# L4.hours              2.332504         2.910554            0.801           0.423
# L4.RD_bratio         -0.413573         0.298772           -1.384           0.166
# L5.tfp                8.380333         5.235687            1.601           0.109
# L5.gdp               -7.181661         4.633079           -1.550           0.121
# L5.investment         0.000120         0.353966            0.000           1.000
# L5.hours              3.674254         2.879907            1.276           0.202
# L5.RD_bratio         -0.450303         0.331780           -1.357           0.175
# ================================================================================
#
# Correlation matrix of residuals
#                    tfp       gdp  investment     hours  RD_bratio
# tfp           1.000000  0.838577    0.707817  0.598659   0.192028
# gdp           0.838577  1.000000    0.960245  0.902885   0.301519
# investment    0.707817  0.960245    1.000000  0.925032   0.278177
# hours         0.598659  0.902885    0.925032  1.000000   0.354266
# RD_bratio     0.192028  0.301519    0.278177  0.354266   1.000000
# Granger Causality Test (x -> y):
# Granger causality F-test. H_0: tfp does not Granger-cause RD_bratio. Conclusion: fail to reject H_0 at 5% significance level.
# =============================================
# Test statistic Critical value p-value    df
# ---------------------------------------------
#          1.700          2.422   0.154 (5, 45)
# ---------------------------------------------
#
# Granger Causality Test (y -> x):
# Granger causality F-test. H_0: RD_bratio does not Granger-cause tfp. Conclusion: reject H_0 at 5% significance level.
# =============================================
# Test statistic Critical value p-value    df
# ---------------------------------------------
#          3.009          2.422   0.020 (5, 45)
# ---------------------------------------------

# %%
var_model(data[['tfp', 'gdp', 'investment', 'hours', 'patent_bratio']], 'patent_bratio', 'tfp')
# Out:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0      -27.42      -27.20   1.236e-12      -27.34
# 1      -40.40      -39.06   2.910e-18      -39.94
# 2      -41.20      -38.76   1.423e-18      -40.36
# 3      -42.55      -39.00   4.768e-19      -41.33
# 4      -43.64      -38.97   2.843e-19      -42.02
# 5     -46.38*     -40.60*  6.114e-20*     -44.39*
# -------------------------------------------------
# Optimal lag order based on AIC: 5
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 08, Dec, 2024
# Time:                     13:49:30
# --------------------------------------------------------------------
# No. of Equations:         5.00000    BIC:                   -40.6038
# Nobs:                     35.0000    HQIC:                  -44.3866
# Log likelihood:           693.350    FPE:                6.11381e-20
# AIC:                     -46.3808    Det(Omega_mle):     3.80192e-21
# --------------------------------------------------------------------
# Results for equation tfp
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -0.196476         0.569885           -0.345           0.730
# L1.tfp                  -0.711124         0.579682           -1.227           0.220
# L1.gdp                   0.947498         0.693270            1.367           0.172
# L1.investment            0.016389         0.066205            0.248           0.804
# L1.hours                -0.790626         0.371456           -2.128           0.033
# L1.patent_bratio        -0.000758         0.003938           -0.193           0.847
# L2.tfp                   1.091098         0.511750            2.132           0.033
# L2.gdp                  -1.991561         0.727224           -2.739           0.006
# L2.investment            0.228864         0.084443            2.710           0.007
# L2.hours                 0.613600         0.342478            1.792           0.073
# L2.patent_bratio         0.008638         0.006955            1.242           0.214
# L3.tfp                  -1.345542         0.708821           -1.898           0.058
# L3.gdp                   1.819005         0.821512            2.214           0.027
# L3.investment           -0.172675         0.064829           -2.664           0.008
# L3.hours                -0.334642         0.367890           -0.910           0.363
# L3.patent_bratio        -0.007761         0.008839           -0.878           0.380
# L4.tfp                   0.778395         0.546538            1.424           0.154
# L4.gdp                  -0.445381         0.654806           -0.680           0.496
# L4.investment           -0.012117         0.056787           -0.213           0.831
# L4.hours                 0.278242         0.291427            0.955           0.340
# L4.patent_bratio         0.009109         0.006363            1.432           0.152
# L5.tfp                  -0.648066         0.495540           -1.308           0.191
# L5.gdp                   0.123072         0.479674            0.257           0.798
# L5.investment            0.059891         0.031500            1.901           0.057
# L5.hours                -0.188817         0.329940           -0.572           0.567
# L5.patent_bratio        -0.011788         0.004131           -2.854           0.004
# ===================================================================================
#
# Results for equation gdp
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -2.088665         1.998637           -1.045           0.296
# L1.tfp                  -1.035932         2.032997           -0.510           0.610
# L1.gdp                   3.750666         2.431359            1.543           0.123
# L1.investment           -0.464918         0.232189           -2.002           0.045
# L1.hours                 0.146562         1.302729            0.113           0.910
# L1.patent_bratio         0.025437         0.013812            1.842           0.066
# L2.tfp                   2.944685         1.794753            1.641           0.101
# L2.gdp                  -5.944087         2.550440           -2.331           0.020
# L2.investment            0.468689         0.296148            1.583           0.114
# L2.hours                 1.672413         1.201102            1.392           0.164
# L2.patent_bratio        -0.007549         0.024392           -0.309           0.757
# L3.tfp                  -4.341733         2.485901           -1.747           0.081
# L3.gdp                   4.062419         2.881118            1.410           0.159
# L3.investment           -0.012190         0.227362           -0.054           0.957
# L3.hours                -2.608395         1.290222           -2.022           0.043
# L3.patent_bratio        -0.013013         0.030998           -0.420           0.675
# L4.tfp                  -0.829990         1.916760           -0.433           0.665
# L4.gdp                   1.417174         2.296463            0.617           0.537
# L4.investment           -0.165131         0.199157           -0.829           0.407
# L4.hours                -0.035985         1.022062           -0.035           0.972
# L4.patent_bratio         0.040189         0.022315            1.801           0.072
# L5.tfp                   0.998491         1.737904            0.575           0.566
# L5.gdp                  -2.165314         1.682260           -1.287           0.198
# L5.investment           -0.055002         0.110472           -0.498           0.619
# L5.hours                 1.254436         1.157131            1.084           0.278
# L5.patent_bratio        -0.021803         0.014487           -1.505           0.132
# ===================================================================================
#
# Results for equation patent_bratio
# ===================================================================================
#                       coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------
# const                   -0.817746        45.795072           -0.018           0.986
# L1.tfp                 -27.636108        46.582368           -0.593           0.553
# L1.gdp                  35.218973        55.710107            0.632           0.527
# L1.investment           -5.193651         5.320174           -0.976           0.329
# L1.hours                -2.282429        29.849624           -0.076           0.939
# L1.patent_bratio         0.956174         0.316475            3.021           0.003
# L2.tfp                  41.356334        41.123444            1.006           0.315
# L2.gdp                 -33.913655        58.438627           -0.580           0.562
# L2.investment           -2.172330         6.785689           -0.320           0.749
# L2.hours                11.692076        27.521040            0.425           0.671
# L2.patent_bratio        -0.946761         0.558901           -1.694           0.090
# L3.tfp                  35.620183        56.959821            0.625           0.532
# L3.gdp                 -35.098535        66.015495           -0.532           0.595
# L3.investment            2.350417         5.209585            0.451           0.652
# L3.hours                21.956153        29.563053            0.743           0.458
# L3.patent_bratio         0.212318         0.710263            0.299           0.765
# L4.tfp                  10.208546        43.919009            0.232           0.816
# L4.gdp                 -31.656287        52.619217           -0.602           0.547
# L4.investment            4.602002         4.563306            1.008           0.313
# L4.hours                 1.338203        23.418656            0.057           0.954
# L4.patent_bratio        -0.515569         0.511304           -1.008           0.313
# L5.tfp                 -55.391218        39.820854           -1.391           0.164
# L5.gdp                  69.204490        38.545891            1.795           0.073
# L5.investment           -2.403338         2.531255           -0.949           0.342
# L5.hours               -34.073525        26.513513           -1.285           0.199
# L5.patent_bratio         0.180417         0.331933            0.544           0.587
# ===================================================================================
#
# Correlation matrix of residuals
#                       tfp       gdp  investment     hours  patent_bratio
# tfp              1.000000  0.860914    0.733428  0.818649      -0.402538
# gdp              0.860914  1.000000    0.970462  0.978264      -0.149884
# investment       0.733428  0.970462    1.000000  0.950155      -0.004289
# hours            0.818649  0.978264    0.950155  1.000000      -0.163193
# patent_bratio   -0.402538 -0.149884   -0.004289 -0.163193       1.000000
# Granger Causality Test (x -> y):
# Granger causality F-test. H_0: tfp does not Granger-cause patent_bratio. Conclusion: fail to reject H_0 at 5% significance level.
# =============================================
# Test statistic Critical value p-value    df
# ---------------------------------------------
#          1.338          2.422   0.266 (5, 45)
# ---------------------------------------------
#
# Granger Causality Test (y -> x):
# Granger causality F-test. H_0: patent_bratio does not Granger-cause tfp. Conclusion: reject H_0 at 5% significance level.
# =============================================
# Test statistic Critical value p-value    df
# ---------------------------------------------
#          3.781          2.422   0.006 (5, 45)
# ---------------------------------------------

# %%
model = sm.OLS(data['patent_bratio'], smdata['RD_bratio']).fit()  #USING PATENT DATA CAN CREATE MORE DATA POINTS ACROSS INDUSTRIES!!! HERE USING R&D CAN ONLY PROVIDE DATA FOR THE AGGREGATE ECONOMY
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:          patent_bratio   R-squared (uncentered):                   0.984
# Model:                            OLS   Adj. R-squared (uncentered):              0.984
# Method:                 Least Squares   F-statistic:                              2428.
# Date:                Sun, 08 Dec 2024   Prob (F-statistic):                    9.70e-37
# Time:                        13:41:09   Log-Likelihood:                         -32.582
# No. Observations:                  40   AIC:                                      67.16
# Df Residuals:                      39   BIC:                                      68.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RD_bratio      5.0997      0.104     49.271      0.000       4.890       5.309
# ==============================================================================
# Omnibus:                       18.836   Durbin-Watson:                   0.354
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.354
# Skew:                          -1.484   Prob(JB):                     5.15e-06
# Kurtosis:                       5.409   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### ADF test to test stationarity
# Decision to use VAR or VECM

# %%
def stationarity_test(data):
    adf_result = adfuller(RD_BRatio['Bratio'])
    
    print("ADF Statistic:", adf_result[0])
    print("p-value:", adf_result[1])
    print("Critical Values:", adf_result[4])
    
    # Decision based on p-value
    alpha = 0.05  # significance level
    if adf_result[1] < alpha:
        print("Reject the null hypothesis (H0): The series is stationary.")
    else:
        print("Fail to reject the null hypothesis (H0): The series has a unit root and is non-stationary.")

# %%
for col in ['bratio', 'tfp', 'gdp', 'investment', 'hours']:
    print(col)
    stationarity_test(data['bratio'])  #CONFIRMING NON-STATIONARITY

# %%
model = VAR(smdata)
lag_order = model.select_order()  # 2 lags is ideal
print(lag_order.summary())  
print(f"Optimal lag order based on AIC: {lag_order.selected_orders['aic']}") #Akaike Information Criterion (AIC) and

# %%
var_model = model.fit(lag_order.selected_orders['aic'])
var_model.summary()

# %%
irf = var_model.irf(10)
irf.plot(impulse='all_patent', orth=False)
plt.show()

# %%
print("Testing if bratio Granger-causes TFP")
grangercausalitytests(smdata[['bratio', 'tfp']], 2, verbose=True)

print("\nTesting if TFP Granger-causes bratio")
grangercausalitytests(smdata[['tfp', 'bratio']], 2, verbose=True)

# %%
print("Testing if bratio Granger-causes output")
grangercausalitytests(smdata[['bratio', 'gdp']], 1, verbose=True)

print("\nTesting if output Granger-causes bratio")
grangercausalitytests(smdata[['gdp', 'bratio']], 1, verbose=True)

# %%
fevd = var_model.fevd(10)
print(fevd.summary())
